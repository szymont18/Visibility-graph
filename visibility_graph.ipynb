# %% [markdown]
# # Graf widoczności

# %% [markdown]
# Przed rozpoczęciem działania programu należy zaimportować zaimplementowane klasy i funkcje. </br>
# Ważne by pliki znajdowały się w tym samym folderze co plik .ipynb

# %%
from util import *
from Obstacle import *
from Graph import * 
from dijkstra import *
from visibility import *
from Visualiser import *

# %% [markdown]
# # I. Rysowanie własnej Sceny
# Pierwszym sposobem na korzystanie z programu jest narysowanie własnej sceny, w której znajdują sie dwa punkty (początkowy i końcowy) oraz przeszkody.</br>
# Punkty dodajemy za pomocą przycisku ,,Dodaj punkty"</br>
# Przeszkody dodajemy za pomocą przycisku ,,Dodaj figury"

# %%
# %matplotlib notebook
user_plot = Plot()
user_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Narysowaną scene można zapisać do pliku z rozszerzeniem .json (nie jest to konieczne). Za nazwę pliku odpowiada zmienna name

# %%
name = "example/example6"
plot_to_write = Plot([user_plot.get_added_elements()])

# %%
with open(name + ".json", 'w') as file:
    file.write(plot_to_write.toJson())

# %% [markdown]
# # II. Gotowe Sceny
# Zamiast rysowania przygotowane zostały również przykładowe wizualizację działania algorytmu. Początkowe sceny pokazane są poniżej

# %%
# %matplotlib notebook
with open('example/example1.json', 'r') as file:
    json1 = file.read()

example1_plot = Plot(json=json1)
example1_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
with open('example/example2.json', 'r') as file:
    json2 = file.read()

example2_plot = Plot(json=json2)
example2_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
with open('example/example3.json', 'r') as file:
    json3 = file.read()

example3_plot = Plot(json=json3)
example3_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
with open('example/example4.json', 'r') as file:
    json4 = file.read()

example4_plot = Plot(json=json4)
example4_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
with open('example/example5.json', 'r') as file:
    json5 = file.read()

example5_plot = Plot(json=json5)
example5_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
with open('example/example6.json', 'r') as file:
    json6 = file.read()

example6_plot = Plot(json=json6)
example6_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # III. Wizualizacja algorytmu

# %% [markdown]
# User Scene

# %%
points, obstacles = get_added_elements(user_plot)

start_point = points[0]
end_point = points[-1]

visible_graph, scenes_g = compute_graph(points, obstacles)
graph_plot = Plot(scenes=scenes_g)
graph_plot.draw()

# %%
distance, parent, scenes = dijkstra(visible_graph, 0, len(points) - 1, True)
dijkstra_plot = Plot(scenes=scenes)
print(distance)
dijkstra_plot.draw()

# %% [markdown]
# Example 1

# %%
points1 = [point for point in example1_plot.scenes[0].points[0].points]
lines1 = [lines_col for lines_col in example1_plot.scenes[0].lines]

points, obstacles = get_added_elements(example1_plot, lines1, points1)

start_point = points[0]
end_point = points[-1]

visible_graph, scenes_g = compute_graph(points, obstacles)
graph_plot = Plot(scenes=scenes_g)
graph_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
distance, parent, scenes = dijkstra(visible_graph, 0, len(points) - 1, True)
dijkstra_plot = Plot(scenes=scenes)
print(distance)
dijkstra_plot.draw()
# Out:
# 0.1044860310088856
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Example 2

# %%
points2 = [point for point in example2_plot.scenes[0].points[0].points]
lines2 = [lines_col for lines_col in example2_plot.scenes[0].lines]

points, obstacles = get_added_elements(example2_plot, lines2, points2)

start_point = points[0]
end_point = points[-1]

visible_graph, scenes_g = compute_graph(points, obstacles)
graph_plot = Plot(scenes=scenes_g)
graph_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
distance, parent, scenes = dijkstra(visible_graph, 0, len(points) - 1, True)
dijkstra_plot = Plot(scenes=scenes)
print(distance)
dijkstra_plot.draw()
# Out:
# 0.1126502069780291
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Example 3

# %%
points3 = [point for point in example3_plot.scenes[0].points[0].points]
lines3 = [lines_col for lines_col in example3_plot.scenes[0].lines]

points, obstacles = get_added_elements(example3_plot, lines3, points3)

start_point = points[0]
end_point = points[-1]

visible_graph, scenes_g = compute_graph(points, obstacles)
graph_plot = Plot(scenes=scenes_g)
graph_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
distance, parent, scenes = dijkstra(visible_graph, 0, len(points) - 1, True)
dijkstra_plot = Plot(scenes=scenes)
print(distance)
dijkstra_plot.draw()
# Out:
# 0.1313890966063228
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Example 4

# %%
points4 = [point for point in example4_plot.scenes[0].points[0].points]
lines4 = [lines_col for lines_col in example4_plot.scenes[0].lines]

points, obstacles = get_added_elements(example1_plot, lines4, points4)

start_point = points[0]
end_point = points[-1]

visible_graph, scenes_g = compute_graph(points, obstacles)
graph_plot = Plot(scenes=scenes_g)
graph_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
distance, parent, scenes = dijkstra(visible_graph, 0, len(points) - 1, True)
dijkstra_plot = Plot(scenes=scenes)
print(distance)
dijkstra_plot.draw()
# Out:
# 0.08827642235651746
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Example 5

# %%
points5 = [point for point in example5_plot.scenes[0].points[0].points]
lines5 = [lines_col for lines_col in example5_plot.scenes[0].lines]

points, obstacles = get_added_elements(example5_plot, lines5, points5)

start_point = points[0]
end_point = points[-1]

visible_graph, scenes_g = compute_graph(points, obstacles)
graph_plot = Plot(scenes=scenes_g)
graph_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
distance, parent, scenes = dijkstra(visible_graph, 0, len(points) - 1, True)
dijkstra_plot = Plot(scenes=scenes)
print(distance)
dijkstra_plot.draw()
# Out:
# 0.09590086023021223
# <img src="data:image/png;base64,..." width="640">

# %%
points6 = [point for point in example6_plot.scenes[0].points[0].points]
lines6 = [lines_col for lines_col in example6_plot.scenes[0].lines]

points, obstacles = get_added_elements(example6_plot, lines6, points6)

start_point = points[0]
end_point = points[-1]

visible_graph, scenes_g = compute_graph(points, obstacles)
graph_plot = Plot(scenes=scenes_g)
graph_plot.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
distance, parent, scenes = dijkstra(visible_graph, 0, len(points) - 1, True)
dijkstra_plot = Plot(scenes=scenes)
print(distance)
dijkstra_plot.draw()
# Out:
# 0.0722457792690532
# <img src="data:image/png;base64,..." width="640">
